# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
steps = 100
x = np.linspace(0,1,steps)

# %%
def exp(x):
    y = np.exp(x)
    return y

# %%
plt.plot(x,exp(x))
plt.xlabel("Time [milliseconds]")
plt.ylabel("Awesomeness")

plt.savefig("prompt7.pdf", bbox_inches = "tight", dpi = 200)

plt.show()
